# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# If the page is local use:
# with open("your_file.html", "r", encoding="utf-8") as file:
#     html = file.read()

# If the table is online, use:
url = "https://admissions.nic.in/UPTAC/applicant/report/orcrreport.aspx?enc=yVQCIiq12npg+pcvNJRdcww8ijHE0M3JICo+UehfedimJjvXET+LsPwN9AEcJEnE"  # replace with your actual page URL
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')


# Find the target table (adjust class or id if needed)
table = soup.find('table', {'id': 'ORCRGridView'})  # based on your screenshot

# Extract headers
headers = [th.get_text(strip=True) for th in table.find('thead').find_all('th')]

# Extract rows
rows = []
for tr in table.find('tbody').find_all('tr'):
    cells = [td.get_text(strip=True) for td in tr.find_all('td')]
    rows.append(cells)

# Create DataFrame
df = pd.DataFrame(rows, columns=headers)

# Save to Excel or CSV
df.to_csv("output.csv", index=False)

# %%
df
# Out:
#      Sr.No    Round                                          Institute  \
# 0        1  Round 1  KIET GROUP OF INSTITUTIONS(KRISHNA INSTT. OF E...
# 1        2  Round 1  KIET GROUP OF INSTITUTIONS(KRISHNA INSTT. OF E...
# 2        3  Round 1            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 3        4  Round 1    INSTITUTE OF ENGG. & RURAL TECHNOLOGY,ALLAHABAD
# 4        5  Round 1    INSTITUTE OF ENGG. & RURAL TECHNOLOGY,ALLAHABAD
# ...    ...      ...                                                ...
# 9294  9295  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 9295  9296  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 9296  9297  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 9297  9298  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 9298  9299  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
#
#                                                 Program  Stream       Quota  \
# ...

# %%
df.drop("Remark",axis=1)
# Out:
#      Sr.No    Round                                          Institute  \
# 0        1  Round 1  KIET GROUP OF INSTITUTIONS(KRISHNA INSTT. OF E...
# 1        2  Round 1  KIET GROUP OF INSTITUTIONS(KRISHNA INSTT. OF E...
# 2        3  Round 1            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 3        4  Round 1    INSTITUTE OF ENGG. & RURAL TECHNOLOGY,ALLAHABAD
# 4        5  Round 1    INSTITUTE OF ENGG. & RURAL TECHNOLOGY,ALLAHABAD
# ...    ...      ...                                                ...
# 9294  9295  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 9295  9296  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 9296  9297  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 9297  9298  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 9298  9299  Round 4            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
#
#                                                 Program  Stream       Quota  \
# ...

# %%
df.head(15)
# Out:
#    Sr.No    Round                                          Institute  \
# 0      1  Round 1  KIET GROUP OF INSTITUTIONS(KRISHNA INSTT. OF E...
# 1      2  Round 1  KIET GROUP OF INSTITUTIONS(KRISHNA INSTT. OF E...
# 2      3  Round 1            RAJKIYA ENGINEERING COLLEGE, PARTAPGARH
# 3      4  Round 1    INSTITUTE OF ENGG. & RURAL TECHNOLOGY,ALLAHABAD
# 4      5  Round 1    INSTITUTE OF ENGG. & RURAL TECHNOLOGY,ALLAHABAD
# 5      6  Round 1  SANSKAR COLLEGE OF ENGINEERING & TECHNOLOGY,GH...
# 6      7  Round 1           UNITED INSTITUTE OF TECHNOLOGY,ALLAHABAD
# 7      8  Round 1           BUDDHA INSTITUTE OF TECHNOLOGY,GORAKHPUR
# 8      9  Round 1           BUDDHA INSTITUTE OF TECHNOLOGY,GORAKHPUR
# 9     10  Round 1               RAJKIYA ENGINEERING COLLEGE,MAINPURI
# 10    11  Round 1               RAJKIYA ENGINEERING COLLEGE,MAINPURI
# 11    12  Round 1               RAJKIYA ENGINEERING COLLEGE,MAINPURI
# 12    13  Round 1              RAJKIYA ENGINEERING COLLEGE, MIRZAPUR
# ...

# %%
df.iloc[[0]]
# Out:
#   Sr.No    Round                                          Institute  \
# 0     1  Round 1  KIET GROUP OF INSTITUTIONS(KRISHNA INSTT. OF E...
#
#                                              Program  Stream       Quota  \
# 0  Computer Science And Engineering(Artificial In...  B.Tech  Home State
#
#   Category                 Seat Gender Opening Rank Closing Rank Remark
# 0   SC(AF)  Both Male and Female Seats    1186728.0    1186728.0

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# If the page is local use:
# with open("your_file.html", "r", encoding="utf-8") as file:
#     html = file.read()

# If the table is online, use:
url = "https://admissions.nic.in/UPTAC/applicant/report/orcrreport.aspx?enc=Nm7QwHILXclJQSv2YVS+7hwSpVykA3HgnWxJU5ug/WL0iltkiRWoMZqp6sExKmRw"  # replace with your actual page URL
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')



# Find the target table (adjust class or id if needed)
table = soup.find('table', {'id': 'ORCRGridView'})  # based on your screenshot

# Extract headers
headers = [th.get_text(strip=True) for th in table.find('thead').find_all('th')]

# Extract rows
rows = []
for tr in table.find('tbody').find_all('tr'):
    cells = [td.get_text(strip=True) for td in tr.find_all('td')]
    rows.append(cells)

# Create DataFrame
df_2023 = pd.DataFrame(rows, columns=headers)

# Save to Excel or CSV
df_2023.to_csv("cutoff2023.csv", index=False)

# %%
df_2023
# Out:
#      Sr.No    Round                                          Institute  \
# 0        1  Round 1  DEEWAN V.S. INSTITUTE OF ENGINEERING & TECHNOL...
# 1        2  Round 1  ASHOKA INSTITUTE OF TECHNOLOGY & MANAGEMENT,VA...
# 2        3  Round 1  ASHOKA INSTITUTE OF TECHNOLOGY & MANAGEMENT,VA...
# 3        4  Round 1      INSTITUTE OF ENGINEERING & TECHNOLOGY,LUCKNOW
# 4        5  Round 1      INSTITUTE OF ENGINEERING & TECHNOLOGY,LUCKNOW
# ...    ...      ...                                                ...
# 7021  7022  Round 6                 RAJKIYA ENGINEERING COLLEGE, BASTI
# 7022  7023  Round 6               RAJKIYA ENGINEERING COLLEGE,AZAMGARH
# 7023  7024  Round 6               RAJKIYA ENGINEERING COLLEGE,AZAMGARH
# 7024  7025  Round 6               RAJKIYA ENGINEERING COLLEGE,AZAMGARH
# 7025  7026  Round 6                 RAJKIYA ENGINEERING COLLEGE, BASTI
#
#                                                 Program  Stream       Quota  \
# ...
