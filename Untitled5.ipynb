# %%
import requests
from bs4 import BeautifulSoup
url="https://admissions.nic.in/UPTAC/applicant/report/orcrreport.aspx?enc=yVQCIiq12npg+pcvNJRdcww8ijHE0M3JICo+UehfedimJjvXET+LsPwN9AEcJEnE"
requests.get(url)
# Out:
# <Response [200]>

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}

webpage = requests.get(url, headers=headers)

# %%
Soup = BeautifulSoup(webpage.content, "html.parser")
print(Soup.prettify() )

# %%
header={" "}
webpage=requests.get("https://admissions.nic.in/UPTAC/applicant/report/orcrreport.aspx?enc=yVQCIiq12npg+pcvNJRdcww8ijHE0M3JICo+UehfedimJjvXET+LsPwN9AEcJEnE")
