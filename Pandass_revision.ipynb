# %%
#leetcode 1st problem dataframe implementation by list

import pandas as pd


data=[]
n=int(input())
for i in range (n):
    student_id=int(input(""))
    age=float(input())
    data.append([student_id,age])
column=['student_id','age']
student_data=pd.DataFrame(data,columns=column1)
print(student_data)
# Out:
# 3
# 10
# 1
# 20
# 1
# 30
# 3
#    student_id  age
# 0          10  1.0
# 1          20  1.0
# 2          30  3.0

# %%
from typing import List  # Import List type for type hinting
import pandas as pd  # Import pandas for DataFrame manipulation

def getDataframeSize(players: pd.DataFrame) -> List[int]:
    return [players.shape[0], players.shape[1]]

# Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [24, 30, 22],
    'Score': [88, 92, 85]
}
players = pd.DataFrame(data)

# Run the function and print the result
size = getDataframeSize(players)
print("DataFrame size (rows, columns):", size)
# Out:
# DataFrame size (rows, columns): [3, 3]

# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2b246a31635a> in <cell line: 2>()
#       1 file_1=open("K:\FAREWELL PHOTOS\DSC_0683.JPG",'wb')
# ----> 2 shutil.copy("R:\python clg\IMG_20200215_143145.jpg","K:\FAREWELL PHOTOS\DSC_0683.JPG")
#
# /usr/lib/python3.10/shutil.py in copy(src, dst, follow_symlinks)
#     415     if os.path.isdir(dst):
#     416         dst = os.path.join(dst, os.path.basename(src))
# --> 417     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418     copymode(src, dst, follow_symlinks=follow_symlinks)
#     419     return dst
#
# /usr/lib/python3.10/shutil.py in copyfile(src, dst, follow_symlinks)
#     252         os.symlink(os.readlink(src), dst)
#     253     else:
# --> 254         with open(src, 'rb') as fsrc:
#     255             try:
#     256                 with open(dst, 'wb') as fdst:
#
# ...
